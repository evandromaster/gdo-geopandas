# %%
def path_db():
    import os
    if os.path.exists(r'I:\Cloud\SQLite\10 - Source\bd_main'):#home
        dir_db = r"I:\Cloud\SQLite\10 - Source\bd_main\gdo.db"
    elif os.path.exists(r"D:\Cloud\SQLite\10 - Source\bd_main"):#office
        dir_db = r"D:\Cloud\SQLite\10 - Source\bd_main\gdo.db"
    else:
        dir_db  = "Arquivo não encontrado!"
    return "sqlite:///" + dir_db    

path_db()
# Out:
# 'sqlite:///D:\\Cloud\\SQLite\\10 - Source\\bd_main\\gdo.db'

# %%
import pandas as pd
df_ocorrencias = pd.read_sql_table('tbl_crimes', path_db(),
                       columns =['NUMERO_REDS', 'DATA_FATO', 'HORARIO_FATO', 'DATA_ULTIMA_ATUALIZACAO', 'DIAO', 
                                 'TENTADO_CONSUMADO_NAT_PRINCIPAL', 'ALVO', 'CAUSA_PRESUMIDA', 'TCV', 'TQF',
                                 'LOGRADOURO_OCORRENCIA', 'BAIRRO', 'BAIRRO_GEO', 'MUNICIPIO', 
                                 'FRACAO', 'CIA', 'UEOP', 'SETOR', 'TIPO', 'LATITUDE_GEO', 'LONGITUDE_GEO'])

# df_ocorrencias['MUN_FRAC'] = df_ocorrencias[['MUNICIPIO', 'FRACAO']].apply(lambda x: ' | '.join(x), axis=1)
#df_ocorrencias.info()




df_thc = pd.read_sql_table('tbl_envolvidos', path_db(),
                        columns =['NUMERO_REDS', 'DATA_FATO', 'HORARIO_FATO', 'DATA_ULTIMA_ATUALIZACAO', 
                                  'CODIGO_SUBCLASSE_NAT_PRINCIPAL','TENTADO_CONSUMADO_NAT_PRINCIPAL',  'HC', 'MUNICIPIO',
                                  'FRACAO', 'CIA', 'UEOP', 'SETOR', 'LATITUDE', 'LONGITUDE'])

df_autores = pd.read_sql_table('tbl_autores', path_db(),
                        columns =['NUMERO_REDS', 'DATA_FATO', 'HORARIO_FATO', 'CODIGO_SUBCLASSE_NAT_PRINCIPAL',
                                  'DESCRICAO_SUBCLASSE_NAT_PRINCIPAL', 'NOME_ENVOLVIDO', 'IDADE_APARENTE',
                                  'TENTADO_CONSUMADO_NAT_PRINCIPAL', 'MUNICIPIO',
                                  'FRACAO', 'CIA', 'UEOP', 'SETOR', 'LATITUDE_GEO', 'LONGITUDE_GEO'])

# df_homicidios['MUN_FRAC'] = df_homicidios[['MUNICIPIO', 'FRACAO']].apply(lambda x: ' | '.join(x), axis=1)
#df_homicidios.dtypes

# %%
#df_autores = pd.read_sql_table('tbl_autores', path_db())

# %%
df_autores.columns
# Index(['NUMERO_REDS', 'DATA_FATO', 'CODIGO_SUBCLASSE_NAT_PRINCIPAL',
#        'TENTADO_CONSUMADO_NAT_PRINCIPAL', 'HORARIO_FATO',
#        'LOGRADOURO_OCORRENCIA', 'LOGRADOURO_OCORRENCIA_NAO_CADASTRADO',
#        'LOGRADOURO_CRUZAMENTO', 'LOGRADOURO_CRUZAMENTO_NAO_CADASTRADO',
#        'BAIRRO', 'BAIRRO_NAO_CADASTRADO', 'COMPLEMENTO_ENDERECO',
#        'PONTO_DE_REFERENCIA', 'MUNICIPIO', 'LATITUDE', 'LONGITUDE',
#        'QTDE_ENVOLVIDOS', 'LATITUDE_GEO', 'LONGITUDE_GEO', 'VALIDADOR_TIPO',
#        'index_right', 'FRACAO', 'CIA', 'SETOR', 'BAIRRO_GEO', 'TIPO', 'UEOP'],
#       dtype='object')
# Out:
# Index(['NUMERO_REDS', 'DATA_FATO', 'HORARIO_FATO',
#        'CODIGO_SUBCLASSE_NAT_PRINCIPAL', 'DESCRICAO_SUBCLASSE_NAT_PRINCIPAL',
#        'NOME_ENVOLVIDO', 'IDADE_APARENTE', 'TENTADO_CONSUMADO_NAT_PRINCIPAL',
#        'MUNICIPIO', 'FRACAO', 'CIA', 'UEOP', 'SETOR', 'LATITUDE_GEO',
#        'LONGITUDE_GEO'],
#       dtype='object')

# %%
# df_ocorrencias = pd.read_sql_table('tbl_crimes', path_db(),
#                        columns =[])

# df_ocorrencias.columns

# %%
df_ocorrencias.columns
# Out:
# Index(['NUMERO_REDS', 'DATA_FATO', 'HORARIO_FATO', 'DATA_ULTIMA_ATUALIZACAO',
#        'DIAO', 'TENTADO_CONSUMADO_NAT_PRINCIPAL', 'ALVO', 'CAUSA_PRESUMIDA',
#        'TCV', 'TQF', 'LOGRADOURO_OCORRENCIA', 'BAIRRO', 'BAIRRO_GEO',
#        'MUNICIPIO', 'FRACAO', 'CIA', 'UEOP', 'SETOR', 'TIPO', 'LATITUDE_GEO',
#        'LONGITUDE_GEO'],
#       dtype='object')

# %%
df_ocorrencias[df_ocorrencias['NUMERO_REDS']=='2021-002828542-001']
# Out:
#              NUMERO_REDS  DATA_FATO HORARIO_FATO DATA_ULTIMA_ATUALIZACAO  \
# 5335  2021-002828542-001 2021-01-13     11:00:00              2021-01-19
#
#         DIAO TENTADO_CONSUMADO_NAT_PRINCIPAL     ALVO CAUSA_PRESUMIDA  TCV  \
# 5335  C01157                       CONSUMADO  VEICULO        IGNORADO    1
#
#       TQF  ...    BAIRRO BAIRRO_GEO               MUNICIPIO  \
# 5335  0.0  ...  INVÁLIDO     CENTRO  SAO SEBASTIAO DO OESTE
#
#                             FRACAO       CIA     UEOP                  SETOR  \
# 5335  3º GP - 3º PEL - 290ª CIA PM  290ª CIA  63º BPM  ITAPECERICA E FRACOES
#
#         TIPO LATITUDE_GEO  LONGITUDE_GEO
# 5335  URBANA    -20.27588     -45.003269
#
# [1 rows x 21 columns]

# %%
df_tcv = df_ocorrencias[df_ocorrencias['TCV']==1]
df_tqf = df_ocorrencias[df_ocorrencias['TQF']==1]

# %%
def path_2020():
    import os
    if os.path.exists(r'I:\Cloud\BI\guardiao_2021\dba\MALACA'): #home verifica se o diretorio exist
        dir_inclusao  = r'I:\Cloud\BI\guardiao_2021\dba\MALACA\Base armazem - 2275.xlsx'
        
    elif os.path.exists(r'D:\Cloud\BI\guardiao_2021\dba\MALACA'):#office verifica se o diretorio exist
        dir_inclusao  = r'D:\Cloud\BI\guardiao_2021\dba\MALACA\Base armazem - 2275.xlsx'
    else:
        dir_inclusao  = "Arquivo não encontrado!"
    return dir_inclusao   

path_2020()
# Out:
# 'D:\\Cloud\\BI\\guardiao_2021\\dba\\MALACA\\Base armazem - 2275.xlsx'

# %%
df_tcv_2021 = df_tcv[df_tcv['DATA_FATO'].dt.year == 2021]

df_tcv_2021 = df_tcv_2021[['NUMERO_REDS', 'DATA_FATO', 'HORARIO_FATO', 'DATA_ULTIMA_ATUALIZACAO', 'DIAO', 'TENTADO_CONSUMADO_NAT_PRINCIPAL', 'ALVO', 'CAUSA_PRESUMIDA', 'TCV', 'LOGRADOURO_OCORRENCIA', 'BAIRRO', 'MUNICIPIO','FRACAO', 'CIA', 'UEOP', 'SETOR', 'LATITUDE_GEO', 'LONGITUDE_GEO']]

# %%
df_tcv_2021.shape
# Out:
# (1286, 18)

# %%
df_reds_2020  = pd.read_excel(path_2020(), sheet_name='2020')

# %%
df_tcv = df_tcv[df_tcv['NUMERO_REDS'].isin(df_reds_2020['NUMERO_REDS'])]

# %%
def path_inclusao():
    import os
    if os.path.exists(r'I:\Cloud\BI\guardiao_2021\dba\MALACA'): #home verifica se o diretorio exist
        dir_inclusao  = r'I:\Cloud\BI\guardiao_2021\dba\MALACA\auditorias_Inclusão_37.xlsx'
    elif os.path.exists(r'D:\Cloud\Jupyter\power_bi\MALACA'):#office verifica se o diretorio exist
        dir_inclusao  = r'D:\Cloud\Jupyter\power_bi\MALACA\auditorias_inclusão_37.xlsx'
    else:
        dir_inclusao  = "Arquivo não encontrado!"
    return dir_inclusao   

path_inclusao()
# Out:
# 'D:\\Cloud\\Jupyter\\power_bi\\MALACA\\auditorias_inclusão_37.xlsx'

# %%
df_inclusao_2020  = pd.read_excel(path_inclusao(), sheet_name='inclusao_2020')
df_tcv = df_tcv.append(df_inclusao_2020)

# %%
df_tcv = df_tcv[['NUMERO_REDS', 'DATA_FATO', 'HORARIO_FATO', 'DATA_ULTIMA_ATUALIZACAO', 'DIAO', 'TENTADO_CONSUMADO_NAT_PRINCIPAL', 'ALVO', 'CAUSA_PRESUMIDA', 'TCV', 'LOGRADOURO_OCORRENCIA', 'BAIRRO', 'MUNICIPIO','FRACAO', 'CIA', 'UEOP', 'SETOR', 'LATITUDE_GEO', 'LONGITUDE_GEO']]
df_tcv.shape
# Out:
# (2312, 18)

# %%
df_tcv
# Out:
#              NUMERO_REDS  DATA_FATO HORARIO_FATO DATA_ULTIMA_ATUALIZACAO  \
# 3121  2020-000106857-001 2020-01-01     21:36:44              2020-01-03
# 3123  2020-000206840-001 2020-01-01     01:00:00              2020-01-03
# 3126  2020-000345619-001 2020-01-01     02:00:00              2020-01-05
# 3129  2020-000133938-001 2020-01-02     03:06:40              2020-01-03
# 3135  2020-000220318-001 2020-01-02     15:54:12              2020-01-03
# ...                  ...        ...          ...                     ...
# 32    2020-004167041-001 2020-01-24     19:30:00              2020-01-27
# 33    2020-001121774-001 2020-01-07     23:59:16              2020-01-10
# 34    2020-024260475-001 2020-05-21     20:10:00              2020-05-23
# 35    2020-022324969-001 2020-05-10     19:30:00              2020-05-12
# 36    2020-006417100-001 2020-02-06     17:35:00              2020-02-08
#
#         DIAO TENTADO_CONSUMADO_NAT_PRINCIPAL                       ALVO  \
# ...

# %%
df_tcv = df_tcv.append(df_tcv_2021)

# %%
df_tcv_20 = df_tcv[df_tcv['DATA_FATO'].dt.year == 2020]
print(df_tcv['NUMERO_REDS'][df_tcv['DATA_FATO'].dt.year == 2020].count(), 'registros CV em 2020')
print(df_tcv['NUMERO_REDS'][df_tcv['DATA_FATO'].dt.year == 2021].count(), ' registros CV em 2021')
# Out:
# 2312 registros CV em 2020
# 1286  registros CV em 2021

# %%
df_tcv
# Out:
#               NUMERO_REDS  DATA_FATO HORARIO_FATO DATA_ULTIMA_ATUALIZACAO  \
# 3121   2020-000106857-001 2020-01-01     21:36:44              2020-01-03
# 3123   2020-000206840-001 2020-01-01     01:00:00              2020-01-03
# 3126   2020-000345619-001 2020-01-01     02:00:00              2020-01-05
# 3129   2020-000133938-001 2020-01-02     03:06:40              2020-01-03
# 3135   2020-000220318-001 2020-01-02     15:54:12              2020-01-03
# ...                   ...        ...          ...                     ...
# 43974  2021-043714605-001 2021-09-09     20:29:00              2021-09-09
# 43975  2021-043709474-001 2021-09-09     20:45:00              2021-09-09
# 43976  2021-043555139-001 2021-09-08     22:30:00              2021-09-09
# 43977  2021-043732165-001 2021-09-09     22:10:00              2021-09-10
# 43978  2021-043731972-001 2021-09-09     23:50:00              2021-09-10
#
#          DIAO TENTADO_CONSUMADO_NAT_PRINCIPAL                 ALVO  \
# ...

# %%
# df_tcv = df_tcv[
#     (
#         (df_tcv['DATA_FATO'].dt.year == 2020)    & (df_tcv['DATA_ULTIMA_ATUALIZACAO']< '2021-01-10')
                  
#                                #         |
    
#         #(df_tcv['COD_DELITO'] == 'B01121')  & (df_tcv['T_C_DELITO'] == 'CONSUMADO')
        
        
        
#     )
# ]
# df_tcv.count()

# %%
def path_audit():
    import os
    if os.path.exists(r'I:\Cloud\SQLite\10 - Source\auditorias'):#home
        dir_classif  = r"I:\Cloud\SQLite\10 - Source\auditorias\Planilha Auditorias 2021.xlsx"
    elif os.path.exists(r'D:\Cloud\SQLite\10 - Source\auditorias'):#office
        dir_classif  = r"D:\Cloud\SQLite\10 - Source\auditorias\Planilha Auditorias 2021.xlsx"
    else:
        dir_classif  = "Arquivo não encontrado!"
    return dir_classif      
path_audit()
# Out:
# 'D:\\Cloud\\SQLite\\10 - Source\\auditorias\\Planilha Auditorias 2021.xlsx'

# %%
#Planilha de  auditorias 2021


df_auditorias = pd.read_excel(path_audit(), sheet_name='tbl_auditorias')
df_auditorias_icv = df_auditorias[(df_auditorias['RESULTADO'] == 'SIM') & (df_auditorias['INDICADOR']== 'ICV')]


df_tcv = df_tcv[~df_tcv['NUMERO_REDS'].isin(df_auditorias_icv['REDS'])]

df_auditorias_icv.count()

#

#df_crimes['DATA_FATO']

#df_crimes['DATA_FATO'] = pd.to_datetime(df_crimes['DATA_FATO'], format='%Y/%m/%d', errors='coerce')



df_tcv = df_tcv[df_tcv['TCV'] == 1]
df_tcv['NUMERO_REDS'][df_tcv['DATA_FATO'].dt.year == 2021].count()
# Out:
# 1247

# %%
df_auditorias_icv.count()
# Out:
# REDS                 43
# NATUREZA             43
# RESULTADO            43
# MUNICÍPIO            43
# CIA PM               31
# TIPO DE AUDITORIA    43
# INDICADOR            43
# OBSERVAÇÃO           34
# Unnamed: 8            3
# Unnamed: 9            1
# dtype: int64

# %%
df_tcv['NUMERO_REDS'][df_tcv['DATA_FATO'].dt.year == 2021].count()
# Out:
# 1247

# %%
# MUNDANÇA DE RESPONSABILIDADE TERRITORIAL
import numpy as np

df_tcv['UEOP'] = np.where(
   (df_tcv['NUMERO_REDS'] =='2021-021949700-001'), '60º BPM', df_tcv['UEOP']
   )


df_tcv['MUNICIPIO'] = np.where(
   (df_tcv['NUMERO_REDS'] =='2021-021949700-001'), 'NOVA SERRANA', df_tcv['MUNICIPIO']
    )


df_tcv['CIA'] = np.where(
   (df_tcv['NUMERO_REDS'] =='2021-021949700-001'), '280ª CIA', df_tcv['CIA']
   )

df_tcv[df_tcv['NUMERO_REDS']=='2021-021949700-001']


df_tcv['UEOP'] = np.where(
   (df_tcv['NUMERO_REDS'] =='2021-020540615-001'), '23º BPM', df_tcv['UEOP']
   )


df_tcv['MUNICIPIO'] = np.where(
   (df_tcv['NUMERO_REDS'] =='2021-020540615-001'), 'DIVINOPOLIS', df_tcv['MUNICIPIO']
    )

# %%
def path_save():
    import os
    if os.path.exists(r'I:\Cloud\BI\guardiao_2021\dba'):#home
        dir_save  = r"I:\Cloud\BI\guardiao_2021\dba\dba_power_bi.xlsx"
    elif os.path.exists(r"D:\Cloud\BI\guardiao_2021\dba"):#office
        dir_save  = r"D:\Cloud\BI\guardiao_2021\dba\dba_power_bi.xlsx"
    else:
        dir_save  = "Arquivo não encontrado!"
    return dir_save    
path_save()
# Out:
# 'D:\\Cloud\\BI\\guardiao_2021\\dba\\dba_power_bi.xlsx'

# %%
# Ordena pela data e salva em um novo DataFrame

df_tcv = df_tcv.sort_values(by='DATA_FATO', ascending=True)
df_tcv
# Out:
#               NUMERO_REDS  DATA_FATO HORARIO_FATO DATA_ULTIMA_ATUALIZACAO  \
# 3121   2020-000106857-001 2020-01-01     21:36:44              2020-01-03
# 30476  2020-000024038-001 2020-01-01     03:00:00              2020-01-02
# 7826   2020-000205560-001 2020-01-01     23:15:00              2020-01-04
# 25724  2020-000118444-001 2020-01-01     22:15:00              2020-01-04
# 43747  2020-000007491-001 2020-01-01     00:05:00              2020-01-02
# ...                   ...        ...          ...                     ...
# 43977  2021-043732165-001 2021-09-09     22:10:00              2021-09-10
# 43973  2021-043607215-001 2021-09-09     12:38:00              2021-09-09
# 43974  2021-043714605-001 2021-09-09     20:29:00              2021-09-09
# 43975  2021-043709474-001 2021-09-09     20:45:00              2021-09-09
# 43978  2021-043731972-001 2021-09-09     23:50:00              2021-09-10
#
#          DIAO TENTADO_CONSUMADO_NAT_PRINCIPAL                 ALVO  \
# ...

# %%
df_tcv = df_tcv[['NUMERO_REDS', 'DATA_FATO', 'HORARIO_FATO', 'DATA_ULTIMA_ATUALIZACAO', 'DIAO', 'TENTADO_CONSUMADO_NAT_PRINCIPAL', 'ALVO', 'CAUSA_PRESUMIDA', 'TCV', 'LOGRADOURO_OCORRENCIA', 'BAIRRO', 'MUNICIPIO','FRACAO', 'CIA', 'UEOP', 'SETOR', 'LATITUDE_GEO', 'LONGITUDE_GEO']]
df_tqf = df_tqf[['NUMERO_REDS', 'DATA_FATO', 'HORARIO_FATO', 'DATA_ULTIMA_ATUALIZACAO', 'DIAO', 'TENTADO_CONSUMADO_NAT_PRINCIPAL', 'ALVO', 'CAUSA_PRESUMIDA', 'TQF', 'MUNICIPIO','FRACAO', 'CIA', 'UEOP', 'SETOR', 'LATITUDE_GEO', 'LONGITUDE_GEO']]

# %%
df_tcv.columns

df_tcv['ALVO'] = df_tcv['ALVO'].replace(['ESTABELECIMENTO COMERCIAL'],'ESTAB. COMERCIAL')

# %%
df_ocorrencias = df_ocorrencias[~df_ocorrencias['DIAO'].isin(['E03015'])]
df_ocorrencias.groupby(['DIAO']).size()#.reset_index(name='QTDE')
# Out:
# DIAO
# B01121      721
# B01148       42
# C01155    36084
# C01157     6077
# C01158      143
# C01159       11
# D01213      185
# D01217      484
# dtype: int64

# %%
df_ocorrencias.columns
# Out:
# Index(['NUMERO_REDS', 'DATA_FATO', 'HORARIO_FATO', 'DATA_ULTIMA_ATUALIZACAO',
#        'DIAO', 'TENTADO_CONSUMADO_NAT_PRINCIPAL', 'ALVO', 'CAUSA_PRESUMIDA',
#        'TCV', 'TQF', 'LOGRADOURO_OCORRENCIA', 'BAIRRO', 'BAIRRO_GEO',
#        'MUNICIPIO', 'FRACAO', 'CIA', 'UEOP', 'SETOR', 'TIPO', 'LATITUDE_GEO',
#        'LONGITUDE_GEO'],
#       dtype='object')

# %%
with pd.ExcelWriter(path_save()) as save:
    df_tcv.to_excel(save, sheet_name='tbl_tcv', index = False)
    df_tqf.to_excel(save, sheet_name='tbl_tqf', index = False)
    df_ocorrencias.to_excel(save, sheet_name='tbl_ocorrencias', index = False)
    df_thc.to_excel(save, sheet_name='tbl_thc', index = False)
    df_autores.to_excel(save, sheet_name='tbl_autores', index = False)

# %%
df_tcv = df_tcv.astype(str)
df_thc = df_thc.astype(str)
df_tcv.dtypes
# Out:
# NUMERO_REDS                        object
# DATA_FATO                          object
# HORARIO_FATO                       object
# DATA_ULTIMA_ATUALIZACAO            object
# DIAO                               object
# TENTADO_CONSUMADO_NAT_PRINCIPAL    object
# ALVO                               object
# CAUSA_PRESUMIDA                    object
# TCV                                object
# LOGRADOURO_OCORRENCIA              object
# BAIRRO                             object
# MUNICIPIO                          object
# FRACAO                             object
# CIA                                object
# UEOP                               object
# SETOR                              object
# LATITUDE_GEO                       object
# LONGITUDE_GEO                      object
# dtype: object

# %%
df_tcv.dtypes
# Out:
# NUMERO_REDS                        object
# DATA_FATO                          object
# HORARIO_FATO                       object
# DATA_ULTIMA_ATUALIZACAO            object
# DIAO                               object
# TENTADO_CONSUMADO_NAT_PRINCIPAL    object
# ALVO                               object
# CAUSA_PRESUMIDA                    object
# TCV                                object
# LOGRADOURO_OCORRENCIA              object
# BAIRRO                             object
# MUNICIPIO                          object
# FRACAO                             object
# CIA                                object
# UEOP                               object
# SETOR                              object
# LATITUDE_GEO                       object
# LONGITUDE_GEO                      object
# dtype: object

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\geo\\anaconda3\\python.exe'

# %%
# #!pip install -- update gspread
# !pip install gspread
# import gspread

# import sys, subprocess
# subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'gspread'])

# %%
import gspread # pip install -- update gspread
gc = gspread.service_account(filename='pysheets-311713-ed072efb0b93.json')

sh = gc.open_by_key("1FGKI3n7HW7kOKljZtzg-z_v9zTPX3o1gLgcmVrC7lHk") # or by sheet name: gc.open("TestList")

worksheet_tcv = sh.get_worksheet(0)
worksheet_thc = sh.get_worksheet(1)
worksheet_tcv.clear()
worksheet_thc.clear()
# Out:
# {'spreadsheetId': '1FGKI3n7HW7kOKljZtzg-z_v9zTPX3o1gLgcmVrC7lHk',
#  'clearedRange': 'tbl_thc!A1:AA1000'}

# %%
#res = worksheet_tcv.get_all_values() # list of lists

sheet_tcv = pd.DataFrame(worksheet_tcv.get_all_records())
sheet_thc = pd.DataFrame(worksheet_thc.get_all_records())

worksheet_tcv.update([df_tcv.columns.values.tolist()] + df_tcv.values.tolist())# envia o dataframe para o googlesheets
worksheet_thc.update([df_thc.columns.values.tolist()] + df_thc.values.tolist())# envia o dataframe para o googlesheets
# Out:
# {'spreadsheetId': '1FGKI3n7HW7kOKljZtzg-z_v9zTPX3o1gLgcmVrC7lHk',
#  'updatedRange': 'tbl_thc!A1:N229',
#  'updatedRows': 229,
#  'updatedColumns': 14,
#  'updatedCells': 3206}

# %%
df_tcv
# Out:
#               NUMERO_REDS   DATA_FATO HORARIO_FATO DATA_ULTIMA_ATUALIZACAO  \
# 3121   2020-000106857-001  2020-01-01     21:36:44              2020-01-03
# 30476  2020-000024038-001  2020-01-01     03:00:00              2020-01-02
# 7826   2020-000205560-001  2020-01-01     23:15:00              2020-01-04
# 25724  2020-000118444-001  2020-01-01     22:15:00              2020-01-04
# 43747  2020-000007491-001  2020-01-01     00:05:00              2020-01-02
# ...                   ...         ...          ...                     ...
# 43977  2021-043732165-001  2021-09-09     22:10:00              2021-09-10
# 43973  2021-043607215-001  2021-09-09     12:38:00              2021-09-09
# 43974  2021-043714605-001  2021-09-09     20:29:00              2021-09-09
# 43975  2021-043709474-001  2021-09-09     20:45:00              2021-09-09
# 43978  2021-043731972-001  2021-09-09     23:50:00              2021-09-10
#
# ...

# %%
worksheet_tcv.update([df_tcv.astype(str).columns.values.tolist()] + df_tcv.astype(str).values.tolist())# envia o dataframe para o googlesheets
# Out:
# {'spreadsheetId': '1FGKI3n7HW7kOKljZtzg-z_v9zTPX3o1gLgcmVrC7lHk',
#  'updatedRange': 'tbl_tcv!A1:R3560',
#  'updatedRows': 3560,
#  'updatedColumns': 18,
#  'updatedCells': 64080}

# %%
df_tcv
# Out:
#               NUMERO_REDS   DATA_FATO HORARIO_FATO DATA_ULTIMA_ATUALIZACAO  \
# 3121   2020-000106857-001  2020-01-01     21:36:44              2020-01-03
# 30476  2020-000024038-001  2020-01-01     03:00:00              2020-01-02
# 7826   2020-000205560-001  2020-01-01     23:15:00              2020-01-04
# 25724  2020-000118444-001  2020-01-01     22:15:00              2020-01-04
# 43747  2020-000007491-001  2020-01-01     00:05:00              2020-01-02
# ...                   ...         ...          ...                     ...
# 43977  2021-043732165-001  2021-09-09     22:10:00              2021-09-10
# 43973  2021-043607215-001  2021-09-09     12:38:00              2021-09-09
# 43974  2021-043714605-001  2021-09-09     20:29:00              2021-09-09
# 43975  2021-043709474-001  2021-09-09     20:45:00              2021-09-09
# 43978  2021-043731972-001  2021-09-09     23:50:00              2021-09-10
#
# ...

# %%
df_tcv.dtypes
#df_homicidios.dtypes
# Out:
# NUMERO_REDS                        object
# DATA_FATO                          object
# HORARIO_FATO                       object
# DATA_ULTIMA_ATUALIZACAO            object
# DIAO                               object
# TENTADO_CONSUMADO_NAT_PRINCIPAL    object
# ALVO                               object
# CAUSA_PRESUMIDA                    object
# TCV                                object
# LOGRADOURO_OCORRENCIA              object
# BAIRRO                             object
# MUNICIPIO                          object
# FRACAO                             object
# CIA                                object
# UEOP                               object
# SETOR                              object
# LATITUDE_GEO                       object
# LONGITUDE_GEO                      object
# dtype: object

# %%
df_tcv[df_tcv['DATA_ULTIMA_ATUALIZACAO']== '2021-05-16']
# Out:
#               NUMERO_REDS   DATA_FATO HORARIO_FATO DATA_ULTIMA_ATUALIZACAO  \
# 5960   2021-023289532-001  2021-05-13     22:10:00              2021-05-16
# 18528  2021-023359909-001  2021-05-14     11:29:10              2021-05-16
# 21595  2021-023470513-001  2021-05-14     22:30:56              2021-05-16
# 27241  2021-023443774-001  2021-05-14     19:11:07              2021-05-16
#
#          DIAO TENTADO_CONSUMADO_NAT_PRINCIPAL                 ALVO  \
# 5960   C01157                       CONSUMADO     ESTAB. COMERCIAL
# 18528  C01157                       CONSUMADO     ESTAB. COMERCIAL
# 21595  C01157                       CONSUMADO  PESSOA / TRANSEUNTE
# 27241  C01157                       CONSUMADO              VEICULO
#
#           CAUSA_PRESUMIDA TCV      LOGRADOURO_OCORRENCIA             BAIRRO  \
# 5960   VANTAGEM ECONOMICA   1                   INVÁLIDO           INVÁLIDO
# 18528  VANTAGEM ECONOMICA   1               ANTONIO NETO  DOUTOR JOSE TOMAZ
# ...

# %%
# df_tcv22 = df_tcv[
#     (
#         (df_tcv['DATA_FATO'].dt.year == 2020) )#   & (df_tcv['DATA_ULTIMA_ATUALIZACAO']< '2021-01-10')
                  
#                                        |
    
#         (df_tcv['COD_DELITO'] == 'B01121')  & (df_tcv['T_C_DELITO'] == 'CONSUMADO')
        
        
#      )
# ]
# df_tcv22.count()

# %%
#df_tcv['NUMERO_REDS'][df_tcv['DATA_FATO'].dt.year == 2021].count()

#df_tcv['NUMERO_REDS'][df_tcv['DATA_FATO'].dt.year == 2020].count()


#df_tqf['NUMERO_REDS'][df_tqf['DATA_FATO'].dt.year == 2021].count()

# %%
df_tcv[df_tcv['NUMERO_REDS']=='2021-021949700-001']
# Out:
#               NUMERO_REDS   DATA_FATO HORARIO_FATO DATA_ULTIMA_ATUALIZACAO  \
# 31141  2021-021949700-001  2021-05-06     12:00:00              2021-05-07
#
#          DIAO TENTADO_CONSUMADO_NAT_PRINCIPAL        ALVO CAUSA_PRESUMIDA TCV  \
# 31141  B01148                       CONSUMADO  RESIDENCIA       PASSIONAL   1
#
#       LOGRADOURO_OCORRENCIA                 BAIRRO     MUNICIPIO       FRACAO  \
# 31141  MARIA ALVARES MACIEL  NOSSA SRA. DE LOURDES  NOVA SERRANA  118ª CIA PM
#
#             CIA     UEOP   SETOR LATITUDE_GEO LONGITUDE_GEO
# 31141  280ª CIA  60º BPM  POMPEU  -19.2281588   -45.0125167

# %%
df_tcv[df_tcv['NUMERO_REDS']=='2021-021949700-001']
# Out:
#               NUMERO_REDS   DATA_FATO HORARIO_FATO DATA_ULTIMA_ATUALIZACAO  \
# 31141  2021-021949700-001  2021-05-06     12:00:00              2021-05-07
#
#          DIAO TENTADO_CONSUMADO_NAT_PRINCIPAL        ALVO CAUSA_PRESUMIDA TCV  \
# 31141  B01148                       CONSUMADO  RESIDENCIA       PASSIONAL   1
#
#       LOGRADOURO_OCORRENCIA                 BAIRRO     MUNICIPIO       FRACAO  \
# 31141  MARIA ALVARES MACIEL  NOSSA SRA. DE LOURDES  NOVA SERRANA  118ª CIA PM
#
#             CIA     UEOP   SETOR LATITUDE_GEO LONGITUDE_GEO
# 31141  280ª CIA  60º BPM  POMPEU  -19.2281588   -45.0125167

# %%
df_tcv
# Out:
#               NUMERO_REDS   DATA_FATO HORARIO_FATO DATA_ULTIMA_ATUALIZACAO  \
# 3121   2020-000106857-001  2020-01-01     21:36:44              2020-01-03
# 30476  2020-000024038-001  2020-01-01     03:00:00              2020-01-02
# 7826   2020-000205560-001  2020-01-01     23:15:00              2020-01-04
# 25724  2020-000118444-001  2020-01-01     22:15:00              2020-01-04
# 43747  2020-000007491-001  2020-01-01     00:05:00              2020-01-02
# ...                   ...         ...          ...                     ...
# 43977  2021-043732165-001  2021-09-09     22:10:00              2021-09-10
# 43973  2021-043607215-001  2021-09-09     12:38:00              2021-09-09
# 43974  2021-043714605-001  2021-09-09     20:29:00              2021-09-09
# 43975  2021-043709474-001  2021-09-09     20:45:00              2021-09-09
# 43978  2021-043731972-001  2021-09-09     23:50:00              2021-09-10
#
# ...

# %%
df_tcv.groupby(['ALVO']).size()
# Out:
# ALVO
# COLETIVO                 23
# ESTAB. COMERCIAL        795
# OUTROS / IGNORADO        92
# PESSOA / TRANSEUNTE    1247
# RESIDENCIA              524
# VEICULO                 878
# dtype: int64

# %%
df_ocorrencias.columns
# Out:
# Index(['NUMERO_REDS', 'DATA_FATO', 'HORARIO_FATO', 'DATA_ULTIMA_ATUALIZACAO',
#        'DIAO', 'TENTADO_CONSUMADO_NAT_PRINCIPAL', 'ALVO', 'CAUSA_PRESUMIDA',
#        'TCV', 'TQF', 'LOGRADOURO_OCORRENCIA', 'BAIRRO', 'BAIRRO_GEO',
#        'MUNICIPIO', 'FRACAO', 'CIA', 'UEOP', 'SETOR', 'TIPO', 'LATITUDE_GEO',
#        'LONGITUDE_GEO'],
#       dtype='object')

# %%
# # MUNDANÇA DE RESPONSABILIDADE TERRITORIAL
# import numpy as np

# df_tcv['UEOP'] = np.where(
#    (df_tcv['NUMERO_REDS'] =='2021-021949700-001') & (df_tcv['UEOP'] == '07º BPM') , '60º BPM', df_tcv['UEOP']
#    )


# df_tcv['MUNICIPIO'] = np.where(
#    (df_tcv['NUMERO_REDS'] =='2021-021949700-001') & (df_tcv['MUNICIPIO'] == 'POMPEU') , 'NOVA SERRANA', df_tcv['MUNICIPIO']
#     )


# df_tcv['CIA'] = np.where(
#    (df_tcv['NUMERO_REDS'] =='2021-021949700-001') & (df_tcv['CIA'] == '118ª CIA') , '280ª CIA', df_tcv['CIA']
#    )

# %%
max(df_tcv['DATA_FATO'])
# Out:
# '2021-09-09'
